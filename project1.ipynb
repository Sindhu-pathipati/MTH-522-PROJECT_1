# %%
import pandas as pd
df = pd.read_csv("/Users/sindhupathipati/Downloads/Crab_Molt 2.csv")
df
# Out:
#      post molt size  pre molt size
# 0             127.7          113.6
# 1             133.2          118.1
# 2             135.3          119.9
# 3             143.3          126.2
# 4             139.3          126.7
# ..              ...            ...
# 467           150.3          135.9
# 468           151.2          135.6
# 469           143.5          129.6
# 470           148.3          134.1
# 471           129.2          114.4
#
# [472 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

post_molt_data = data['post molt size']


# Create a histogram 
sns.histplot(post_molt_data, bins=30, kde=True,color = 'grey')
plt.title('post molt size Histogram')
plt.xlabel('Post Molt Size')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pre_molt_data = data['pre molt size']


# Create a histogram 
sns.histplot(post_molt_data, bins=30, kde=True,color = 'green')
plt.title('pre molt size Histogram')
plt.xlabel('Pre Molt Size')
plt.ylabel('Frequency')
plt.show()

# %%
import scipy.stats as stats

post_molt_data = df['post molt size'] 

#create a quantile plot
stats.probplot(post_molt_data, dist="norm", plot=plt)

#
plt.title('Quantile plot of Post Molt Size ')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')

# Show the plot
plt.show()

# %%
import scipy.stats as stats

pre_molt_data = df['pre molt size'] 

#create a quantile plot
stats.probplot(pre_molt_data, dist="norm", plot=plt)


plt.title('Quantile plot of Pre Molt Size ')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')

# Show the plot
plt.show()

# %%
from scipy.stats import skew, kurtosis

pre_molt_data = data['pre molt size'] 

# Calculate statistics values
mean_value = np.mean(pre_molt_data)
median_value = np.median(pre_molt_data)
min_value = np.min(pre_molt_data)
max_value = np.max(pre_molt_data)
skewness_value = skew(pre_molt_data)
kurtosis_value = kurtosis(pre_molt_data)

# Print the statistics values
print(f'Mean: {mean_value}')
print(f'Median: {median_value}')
print(f'Min: {min_value}')
print(f'Max: {max_value}')
print(f'Skewness: {skewness_value}')
print(f'Kurtosis: {kurtosis_value}')
# Out:
# Mean: 129.21186440677965
# Median: 132.8
# Min: 31.1
# Max: 155.1
# Skewness: -2.0034871763549766
# Kurtosis: 6.766321650922

# %%
from scipy.stats import skew, kurtosis

post_molt_data = data['post molt size'] 

# Calculate statistics values
mean_value = np.mean(post_molt_data)
median_value = np.median(post_molt_data)
min_value = np.min(post_molt_data)
max_value = np.max(post_molt_data)
skewness_value = skew(post_molt_data)
kurtosis_value = kurtosis(post_molt_data)

# Print the statistics values
print(f'Mean: {mean_value}')
print(f'Median: {median_value}')
print(f'Min: {min_value}')
print(f'Max: {max_value}')
print(f'Skewness: {skewness_value}')
print(f'Kurtosis: {kurtosis_value}')
# Out:
# Mean: 143.89766949152542
# Median: 147.4
# Min: 38.8
# Max: 166.8
# Skewness: -2.3469021583966594
# Kurtosis: 10.116042372071325

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

#Generating synthetic data for post-molt and pre-molt sizes
np.random.seed(42)
post_molt_size = np.random.normal(loc=110, scale=15, size=100)
pre_molt_size = np.random.normal(loc=95, scale=15, size=100)

# Set up the figure and axis
plt.figure(figsize=(10, 6))
sns.set(style="darkgrid")

# Plot KDE with different bandwidth and transparency
sns.kdeplot(post_molt_size, label="Post-Molt Size",  fill=True, alpha=0.2, color="red")
sns.kdeplot(pre_molt_size, label="Pre-Molt Size",  fill=True, alpha=0.2, color="green")

# Adding labels, title, and legend
plt.xlabel('Size')
plt.ylabel('Density')
plt.title('Post-Molt Size vs Pre-Molt Size')

# Customizing the legend
plt.legend(title="Size Distribution", loc='upper left', fontsize=10, title_fontsize='13')

# Display the plot
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")


sns.ecdfplot(data=df, x='post molt size', label='Post Molt Size') 
sns.ecdfplot(data=df, x='pre molt size', label='Pre Molt Size')

#Set plot labels and title

plt.xlabel('Size') 
plt.ylabel('Cumulative Probability')

plt.title('Comparison of Cumulative Distributions of Post Molt Size and Pre Molt Size')

#Show the plot 
plt.legend() 
plt.show()

# %%
Spost = df['post molt size']
Spre = df['pre molt size']


# Function to calculate Cohen's d
def cohens_d(group1, group2):
    mean1, mean2 = np.mean(group1), np.mean(group2)
    std1, std2 = np.std(group1, ddof=1), np.std(group2, ddof=1)
    n1, n2 = len(group1), len(group2)
    pooled_std = np.sqrt(((n1 - 1) * std1**2 + (n2 - 1) * std2**2) / (n1 + n2 - 2))
    if (mean1 - mean2) / pooled_std  < 0 :
        return((mean1 - mean2) / pooled_std)*(-1)
    else:
        return (mean1 - mean2) / pooled_std

mpost = np.mean(Spost)
mpre = np.mean(Spre)

print(f"Mean size post molt: {mpost:.2f}")
print(f"Mean size pre molt: {mpre:.2f}")


# Calculate Cohen's d
cd_value = cohens_d(Spost, Spre)
print(f"Cohen's d: {cd_value:.2f}")


if cd_value < 0.2:
    print("Effect size is small.")
elif cd_value < 0.5:
    print("Effect size is medium.")
else:
    print("Effect size is large.")
# Out:
# Mean size post molt: 143.90
# Mean size pre molt: 129.21
# Cohen's d: 0.96
# Effect size is large.

# %%
pre_molt_size_data = df['pre molt size']
post_molt_size_data = df['post molt size']
# Calculating the observed test statistic (e.g., difference in means)
observed_statistic = np.mean(post_molt_size_data) - np.mean(pre_molt_size_data)
num_permutatIons = 1006
# Initializing an array to store permutation test statistics
perm_test_statistics = np. zeros(num_permutations)
#Permutation_test
for i in range(num_permutations):
    # Concatenate the data and shuffle
    combined_data = np.concatenate((pre_molt_size_data, post_molt_size_data))
    np.random.shuffle(combined_data)
    # Calculate the test statistic for the permuted data
    perm_test_statistics[i] = np.mean(combined_data[:len(pre_molt_size_data)]) - np.mean(combined_data[len(pre_molt_size_data)])
# Calculating p-value
P_value = (np.abs(perm_test_statistics) >= np.abs(observed_statistic)).mean()
# Print the result
print(f"observed statistic: {observed_statistic}")
print (f"P-value: {p_value}")
# Out:
# observed statistic: 14.685805084745766
# P-value: 0.0

# %%
# Extracting pre-molt size and post-molt size data
pre_molt_size_data = df['pre molt size']
post_molt_size_data = df['post molt size']
# Performing t-test
t_statistic, p_value = ttest_ind(pre_molt_size_data, post_molt_size_data, equal_var=False)
# Displaying the results
print(f"T-statistic: {t_statistic}")
print(f"p-Value: {p_value}")
# Check for statistical significance (common significance level is 0.05)
alpha = 0.05
if p_value < alpha:
    print ("The mean difference is statistically significant.")
else:
    print ("The mean difference is not statistically significant.")
# Out:
# T-statistic: -14.779567045859308
# p-Value: 1.392686580034457e-44
# The mean difference is statistically significant.
